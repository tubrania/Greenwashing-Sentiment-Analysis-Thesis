# %% [markdown]
# # 01_Extract Text (from PDF files)

# %% [markdown]
# ### Impoart Libraries

# %%
import numpy as np
import pandas as pd

# %%
import os
from nltk.tokenize import sent_tokenize

# %%
import fitz

# %% [markdown]
# ### Define File Paths

# %%
path_pdf  = 'Reports'
fname_out = 'sentences.csv'

# %% [markdown]
# ### Define Function: Get count of words (only alphabets)

# %%
def get_cnt(text):
    cnt = 0
    for word in text.split():
        if word.isalpha():
            cnt += 1
    return cnt

# %% [markdown]
# ### Define Function: Get text from blocks

# %%
def get_text(block_lst):

    MIN_WORD_CNT = 10
    
    text_lst = []
    for block in block_lst:
        if block[6] != 0: continue # block_type: 0 = text
    
        text = block[4]
        text = text.replace('fi ', 'fi') # PyMuPDF(fitz) bug fix: 'fi ' --> 'fi'
    
        if get_cnt(text) < MIN_WORD_CNT: continue # Delete sentences with less than MIN_WORD_CNT(10) 
    
        text_lst.append(text.replace('-\n', ''))
        
    return ('\n'.join(text_lst))

# %% [markdown]
# ### Define Function: Get sentences from PDF files

# %%
def get_sentence(fname, skip_page = (0,)):
 
    doc = fitz.open(fname)
    
    sent_lst = []
    
    for page_no, page in enumerate(doc):

        # Skip page
        if page_no+1 in skip_page: continue
        block_lst = page.get_text('blocks')
        text = get_text(block_lst)
    
        for i, sentence in enumerate(sent_tokenize(text)):
            r_sent = ' '.join(sentence.split()) # Delete '\n', '\t' and strip
            sent_lst.append(r_sent)
            
    doc.close()

    return sent_lst

# %% [markdown]
# ### Define Function: Generate document (DataFrame)

# %%
def gen_document(doc_id, fname, sent_lst):

    res_df = pd.DataFrame(
        {
            'doc_id': doc_id,
            'fname': fname,
            'sentence': sent_lst
        }
    )
    
    return res_df

# %% [markdown]
# ### Define Function: Read PDF file list

# %%
def read_filelist(path):

    # Create empty DataFrame
    df = pd.DataFrame()
    
    # Read file list (directory)
    for idx, fname in enumerate(os.listdir(path)):
        p_fname = os.path.join(path, fname)
        #p_fname = path +'/'+fname
        print('path + fname >>>', p_fname)
        
        if p_fname.split('.')[-1] != 'pdf': continue
        print('fname >>>',fname)
    
        doc_id = int(idx)
        
        print(f'doc_id = [{doc_id}], fname = [{fname}]')
        print('')
    
        sent_lst = get_sentence(p_fname)
        df_doc   = gen_document(doc_id, fname, sent_lst)
        
        df = pd.concat([df,df_doc])
        
    return df

# %% [markdown]
# ### Create DataFrame from PDF Files

# %%
# %%time
df = read_filelist(path_pdf)
print('==== End of jobs ====')
# Out:
# path + fname >>> reports\Aldi_2020.pdf
# fname >>> Aldi_2020.pdf
# doc_id = [0], fname = [Aldi_2020.pdf]
#
# path + fname >>> reports\Aldi_2021.pdf
# fname >>> Aldi_2021.pdf
# doc_id = [1], fname = [Aldi_2021.pdf]
#
# path + fname >>> reports\Allianz_2020.pdf
# fname >>> Allianz_2020.pdf
# doc_id = [2], fname = [Allianz_2020.pdf]
#
# path + fname >>> reports\Allianz_2021.pdf
# fname >>> Allianz_2021.pdf
# doc_id = [3], fname = [Allianz_2021.pdf]
#
# path + fname >>> reports\amazon_2020.pdf
# fname >>> amazon_2020.pdf
# doc_id = [4], fname = [amazon_2020.pdf]
#
# path + fname >>> reports\amazon_2021.pdf
# fname >>> amazon_2021.pdf
# doc_id = [5], fname = [amazon_2021.pdf]
#
# path + fname >>> reports\Asklepios_2020.pdf
# fname >>> Asklepios_2020.pdf
# doc_id = [6], fname = [Asklepios_2020.pdf]
#
# path + fname >>> reports\Asklepios_2021.pdf
# fname >>> Asklepios_2021.pdf
# doc_id = [7], fname = [Asklepios_2021.pdf]
#
# path + fname >>> reports\Axel Springer_2020.pdf
# fname >>> Axel Springer_2020.pdf
# doc_id = [8], fname = [Axel Springer_2020.pdf]
#
# path + fname >>> reports\Axel Springer_2021.pdf
# fname >>> Axel Springer_2021.pdf
# doc_id = [9], fname = [Axel Springer_2021.pdf]
#
# path + fname >>> reports\bayerische landesbank_2020.pdf
# fname >>> bayerische landesbank_2020.pdf
# doc_id = [10], fname = [bayerische landesbank_2020.pdf]
#
# path + fname >>> reports\bayerische landesbank_2021.pdf
# fname >>> bayerische landesbank_2021.pdf
# doc_id = [11], fname = [bayerische landesbank_2021.pdf]
#
# path + fname >>> reports\Bayer_2020.pdf
# fname >>> Bayer_2020.pdf
# doc_id = [12], fname = [Bayer_2020.pdf]
#
# path + fname >>> reports\Bayer_2021.pdf
# fname >>> Bayer_2021.pdf
# doc_id = [13], fname = [Bayer_2021.pdf]
#
# path + fname >>> reports\Beiersdorf_2020.pdf
# fname >>> Beiersdorf_2020.pdf
# doc_id = [14], fname = [Beiersdorf_2020.pdf]
#
# path + fname >>> reports\Beiersdorf_2021.pdf
# fname >>> Beiersdorf_2021.pdf
# doc_id = [15], fname = [Beiersdorf_2021.pdf]
#
# path + fname >>> reports\Bertelsmann_2020.pdf
# fname >>> Bertelsmann_2020.pdf
# doc_id = [16], fname = [Bertelsmann_2020.pdf]
#
# path + fname >>> reports\Bertelsmann_2021.pdf
# fname >>> Bertelsmann_2021.pdf
# doc_id = [17], fname = [Bertelsmann_2021.pdf]
#
# path + fname >>> reports\BMW_2020.pdf
# fname >>> BMW_2020.pdf
# doc_id = [18], fname = [BMW_2020.pdf]
#
# path + fname >>> reports\BMW_2021.pdf
# fname >>> BMW_2021.pdf
# doc_id = [19], fname = [BMW_2021.pdf]
#
# path + fname >>> reports\bosch_2020.pdf
# fname >>> bosch_2020.pdf
# doc_id = [20], fname = [bosch_2020.pdf]
#
# path + fname >>> reports\bosch_2021.pdf
# fname >>> bosch_2021.pdf
# doc_id = [21], fname = [bosch_2021.pdf]
#
# path + fname >>> reports\carl zeiss_2020.pdf
# fname >>> carl zeiss_2020.pdf
# doc_id = [22], fname = [carl zeiss_2020.pdf]
#
# path + fname >>> reports\carl zeiss_2021.pdf
# fname >>> carl zeiss_2021.pdf
# doc_id = [23], fname = [carl zeiss_2021.pdf]
#
# path + fname >>> reports\commerzbank_2020.pdf
# fname >>> commerzbank_2020.pdf
# doc_id = [24], fname = [commerzbank_2020.pdf]
#
# path + fname >>> reports\commerzbank_2021.pdf
# fname >>> commerzbank_2021.pdf
# doc_id = [25], fname = [commerzbank_2021.pdf]
#
# path + fname >>> reports\Debeka_2020.pdf
# fname >>> Debeka_2020.pdf
# doc_id = [26], fname = [Debeka_2020.pdf]
#
# path + fname >>> reports\Debeka_2021.pdf
# fname >>> Debeka_2021.pdf
# doc_id = [27], fname = [Debeka_2021.pdf]
#
# path + fname >>> reports\DEERE_2020.pdf
# fname >>> DEERE_2020.pdf
# doc_id = [28], fname = [DEERE_2020.pdf]
#
# path + fname >>> reports\DEERE_2021.pdf
# fname >>> DEERE_2021.pdf
# doc_id = [29], fname = [DEERE_2021.pdf]
#
# path + fname >>> reports\DEKRA_2020.pdf
# fname >>> DEKRA_2020.pdf
# doc_id = [30], fname = [DEKRA_2020.pdf]
#
# path + fname >>> reports\DEKRA_2021.pdf
# fname >>> DEKRA_2021.pdf
# doc_id = [31], fname = [DEKRA_2021.pdf]
#
# path + fname >>> reports\desktop.ini
# path + fname >>> reports\Deutsche Bank_2020.pdf
# fname >>> Deutsche Bank_2020.pdf
# doc_id = [33], fname = [Deutsche Bank_2020.pdf]
#
# path + fname >>> reports\Deutsche Bank_2021.pdf
# fname >>> Deutsche Bank_2021.pdf
# doc_id = [34], fname = [Deutsche Bank_2021.pdf]
#
# path + fname >>> reports\dm_2020.pdf
# fname >>> dm_2020.pdf
# doc_id = [35], fname = [dm_2020.pdf]
#
# path + fname >>> reports\dm_2021.pdf
# fname >>> dm_2021.pdf
# doc_id = [36], fname = [dm_2021.pdf]
#
# path + fname >>> reports\Draeger_2020.pdf
# fname >>> Draeger_2020.pdf
# doc_id = [37], fname = [Draeger_2020.pdf]
#
# path + fname >>> reports\Draeger_2021.pdf
# fname >>> Draeger_2021.pdf
# doc_id = [38], fname = [Draeger_2021.pdf]
#
# path + fname >>> reports\DZ BANK_2020.pdf
# fname >>> DZ BANK_2020.pdf
# doc_id = [39], fname = [DZ BANK_2020.pdf]
#
# path + fname >>> reports\DZ BANK_2021.pdf
# fname >>> DZ BANK_2021.pdf
# doc_id = [40], fname = [DZ BANK_2021.pdf]
#
# path + fname >>> reports\EON_2020.pdf
# fname >>> EON_2020.pdf
# doc_id = [41], fname = [EON_2020.pdf]
#
# path + fname >>> reports\EON_2021.pdf
# fname >>> EON_2021.pdf
# doc_id = [42], fname = [EON_2021.pdf]
#
# path + fname >>> reports\Ernst & Young_2020.pdf
# fname >>> Ernst & Young_2020.pdf
# doc_id = [43], fname = [Ernst & Young_2020.pdf]
#
# path + fname >>> reports\Ernst & Young_2021.pdf
# fname >>> Ernst & Young_2021.pdf
# doc_id = [44], fname = [Ernst & Young_2021.pdf]
#
# path + fname >>> reports\evonik_2020.pdf
# fname >>> evonik_2020.pdf
# doc_id = [45], fname = [evonik_2020.pdf]
#
# path + fname >>> reports\evonik_2021.pdf
# fname >>> evonik_2021.pdf
# doc_id = [46], fname = [evonik_2021.pdf]
#
# path + fname >>> reports\Generali_2020.pdf
# fname >>> Generali_2020.pdf
# doc_id = [47], fname = [Generali_2020.pdf]
#
# path + fname >>> reports\Generali_2021.pdf
# fname >>> Generali_2021.pdf
# doc_id = [48], fname = [Generali_2021.pdf]
#
# path + fname >>> reports\henkel_2020.pdf
# fname >>> henkel_2020.pdf
# doc_id = [49], fname = [henkel_2020.pdf]
#
# path + fname >>> reports\henkel_2021.pdf
# fname >>> henkel_2021.pdf
# doc_id = [50], fname = [henkel_2021.pdf]
#
# path + fname >>> reports\HUK COBURG_2020.pdf
# fname >>> HUK COBURG_2020.pdf
# doc_id = [51], fname = [HUK COBURG_2020.pdf]
#
# path + fname >>> reports\HUK COBURG_2021.pdf
# fname >>> HUK COBURG_2021.pdf
# doc_id = [52], fname = [HUK COBURG_2021.pdf]
#
# path + fname >>> reports\ibm_2020.pdf
# fname >>> ibm_2020.pdf
# doc_id = [53], fname = [ibm_2020.pdf]
#
# path + fname >>> reports\ibm_2021.pdf
# fname >>> ibm_2021.pdf
# doc_id = [54], fname = [ibm_2021.pdf]
#
# path + fname >>> reports\Infineon_2020.pdf
# fname >>> Infineon_2020.pdf
# doc_id = [55], fname = [Infineon_2020.pdf]
#
# path + fname >>> reports\Infineon_2021.pdf
# fname >>> Infineon_2021.pdf
# doc_id = [56], fname = [Infineon_2021.pdf]
#
# path + fname >>> reports\ing_2020.pdf
# fname >>> ing_2020.pdf
# doc_id = [57], fname = [ing_2020.pdf]
#
# path + fname >>> reports\ing_2021.pdf
# fname >>> ing_2021.pdf
# doc_id = [58], fname = [ing_2021.pdf]
#
# path + fname >>> reports\KfW_2020.pdf
# fname >>> KfW_2020.pdf
# doc_id = [59], fname = [KfW_2020.pdf]
#
# path + fname >>> reports\KfW_2021.pdf
# fname >>> KfW_2021.pdf
# doc_id = [60], fname = [KfW_2021.pdf]
#
# path + fname >>> reports\kpmg_2020.pdf
# fname >>> kpmg_2020.pdf
# doc_id = [61], fname = [kpmg_2020.pdf]
#
# path + fname >>> reports\kpmg_2021.pdf
# fname >>> kpmg_2021.pdf
# doc_id = [62], fname = [kpmg_2021.pdf]
#
# path + fname >>> reports\landesbank baden württemberg_2020.pdf
# fname >>> landesbank baden württemberg_2020.pdf
# doc_id = [63], fname = [landesbank baden württemberg_2020.pdf]
#
# path + fname >>> reports\Landesbank Baden Württemberg_2021.pdf
# fname >>> Landesbank Baden Württemberg_2021.pdf
# doc_id = [64], fname = [Landesbank Baden Württemberg_2021.pdf]
#
# path + fname >>> reports\LANXESS_2020.pdf
# fname >>> LANXESS_2020.pdf
# doc_id = [65], fname = [LANXESS_2020.pdf]
#
# path + fname >>> reports\LANXESS_2021.pdf
# fname >>> LANXESS_2021.pdf
# doc_id = [66], fname = [LANXESS_2021.pdf]
#
# path + fname >>> reports\Linde_2020.pdf
# fname >>> Linde_2020.pdf
# doc_id = [67], fname = [Linde_2020.pdf]
#
# path + fname >>> reports\Linde_2021.pdf
# fname >>> Linde_2021.pdf
# doc_id = [68], fname = [Linde_2021.pdf]
#
# path + fname >>> reports\mahle_2020.pdf
# fname >>> mahle_2020.pdf
# doc_id = [69], fname = [mahle_2020.pdf]
#
# path + fname >>> reports\mahle_2021.pdf
# fname >>> mahle_2021.pdf
# doc_id = [70], fname = [mahle_2021.pdf]
#
# path + fname >>> reports\Mercedes Benz_2020.pdf
# fname >>> Mercedes Benz_2020.pdf
# doc_id = [71], fname = [Mercedes Benz_2020.pdf]
#
# path + fname >>> reports\Mercedes Benz_2021.pdf
# fname >>> Mercedes Benz_2021.pdf
# doc_id = [72], fname = [Mercedes Benz_2021.pdf]
# path + fname >>> reports\merck_2020.pdf
# fname >>> merck_2020.pdf
# doc_id = [73], fname = [merck_2020.pdf]
#
# path + fname >>> reports\merck_2021.pdf
# fname >>> merck_2021.pdf
# doc_id = [74], fname = [merck_2021.pdf]
#
# path + fname >>> reports\Munich Re_2021.pdf
# fname >>> Munich Re_2021.pdf
# doc_id = [75], fname = [Munich Re_2021.pdf]
#
# path + fname >>> reports\MunichRe_2020.pdf
# fname >>> MunichRe_2020.pdf
# doc_id = [76], fname = [MunichRe_2020.pdf]
#
# path + fname >>> reports\Philip Morris_2020.pdf
# fname >>> Philip Morris_2020.pdf
# doc_id = [77], fname = [Philip Morris_2020.pdf]
#
# path + fname >>> reports\Philip Morris_2021.pdf
# fname >>> Philip Morris_2021.pdf
# doc_id = [78], fname = [Philip Morris_2021.pdf]
#
# path + fname >>> reports\Procter Gamble_2020.pdf
# fname >>> Procter Gamble_2020.pdf
# doc_id = [79], fname = [Procter Gamble_2020.pdf]
#
# path + fname >>> reports\Procter Gamble_2021.pdf
# fname >>> Procter Gamble_2021.pdf
# doc_id = [80], fname = [Procter Gamble_2021.pdf]
#
# path + fname >>> reports\pwc_2020.pdf
# fname >>> pwc_2020.pdf
# doc_id = [81], fname = [pwc_2020.pdf]
#
# path + fname >>> reports\pwc_2021.pdf
# fname >>> pwc_2021.pdf
# doc_id = [82], fname = [pwc_2021.pdf]
#
# path + fname >>> reports\REWE_2020.pdf
# fname >>> REWE_2020.pdf
# doc_id = [83], fname = [REWE_2020.pdf]
#
# path + fname >>> reports\REWE_2021.pdf
# fname >>> REWE_2021.pdf
# doc_id = [84], fname = [REWE_2021.pdf]
#
# path + fname >>> reports\rwe_2020.pdf
# fname >>> rwe_2020.pdf
# doc_id = [85], fname = [rwe_2020.pdf]
#
# path + fname >>> reports\rwe_2021.pdf
# fname >>> rwe_2021.pdf
# doc_id = [86], fname = [rwe_2021.pdf]
#
# path + fname >>> reports\Salzgitter_2020.pdf
# fname >>> Salzgitter_2020.pdf
# doc_id = [87], fname = [Salzgitter_2020.pdf]
#
# path + fname >>> reports\Salzgitter_2021.pdf
# fname >>> Salzgitter_2021.pdf
# doc_id = [88], fname = [Salzgitter_2021.pdf]
#
# path + fname >>> reports\Sanofi_2020.pdf
# fname >>> Sanofi_2020.pdf
# doc_id = [89], fname = [Sanofi_2020.pdf]
#
# path + fname >>> reports\Sanofi_2021.pdf
# fname >>> Sanofi_2021.pdf
# doc_id = [90], fname = [Sanofi_2021.pdf]
#
# path + fname >>> reports\SAP_2020.pdf
# fname >>> SAP_2020.pdf
# doc_id = [91], fname = [SAP_2020.pdf]
#
# path + fname >>> reports\SAP_2021.pdf
# fname >>> SAP_2021.pdf
# doc_id = [92], fname = [SAP_2021.pdf]
#
# path + fname >>> reports\schaeffler_2020.pdf
# fname >>> schaeffler_2020.pdf
# doc_id = [93], fname = [schaeffler_2020.pdf]
#
# path + fname >>> reports\schaeffler_2021.pdf
# fname >>> schaeffler_2021.pdf
# doc_id = [94], fname = [schaeffler_2021.pdf]
#
# path + fname >>> reports\shell_2020.pdf
# fname >>> shell_2020.pdf
# doc_id = [95], fname = [shell_2020.pdf]
#
# path + fname >>> reports\shell_2021.pdf
# fname >>> shell_2021.pdf
# doc_id = [96], fname = [shell_2021.pdf]
#
# path + fname >>> reports\Siemens_2020.pdf
# fname >>> Siemens_2020.pdf
# doc_id = [97], fname = [Siemens_2020.pdf]
#
# path + fname >>> reports\Siemens_2021.pdf
# fname >>> Siemens_2021.pdf
# doc_id = [98], fname = [Siemens_2021.pdf]
#
# path + fname >>> reports\strabag_2020.pdf
# fname >>> strabag_2020.pdf
# doc_id = [99], fname = [strabag_2020.pdf]
#
# path + fname >>> reports\strabag_2021.pdf
# fname >>> strabag_2021.pdf
# doc_id = [100], fname = [strabag_2021.pdf]
#
# path + fname >>> reports\Talanx_2020.pdf
# fname >>> Talanx_2020.pdf
# doc_id = [101], fname = [Talanx_2020.pdf]
#
# path + fname >>> reports\Talanx_2021.pdf
# fname >>> Talanx_2021.pdf
# doc_id = [102], fname = [Talanx_2021.pdf]
#
# path + fname >>> reports\Telefonica_2020.pdf
# fname >>> Telefonica_2020.pdf
# doc_id = [103], fname = [Telefonica_2020.pdf]
#
# path + fname >>> reports\Telefonica_2021.pdf
# fname >>> Telefonica_2021.pdf
# doc_id = [104], fname = [Telefonica_2021.pdf]
#
# path + fname >>> reports\telekom_2020.pdf
# fname >>> telekom_2020.pdf
# doc_id = [105], fname = [telekom_2020.pdf]
#
# path + fname >>> reports\telekom_2021.pdf
# fname >>> telekom_2021.pdf
# doc_id = [106], fname = [telekom_2021.pdf]
#
# path + fname >>> reports\United Internet_2020.pdf
# fname >>> United Internet_2020.pdf
# doc_id = [107], fname = [United Internet_2020.pdf]
#
# path + fname >>> reports\United Internet_2021.pdf
# fname >>> United Internet_2021.pdf
# doc_id = [108], fname = [United Internet_2021.pdf]
#
# path + fname >>> reports\VINCI_2020.pdf
# fname >>> VINCI_2020.pdf
# doc_id = [109], fname = [VINCI_2020.pdf]
#
# path + fname >>> reports\VINCI_2021.pdf
# fname >>> VINCI_2021.pdf
# doc_id = [110], fname = [VINCI_2021.pdf]
#
# path + fname >>> reports\volkswagen_2020.pdf
# fname >>> volkswagen_2020.pdf
# doc_id = [111], fname = [volkswagen_2020.pdf]
#
# path + fname >>> reports\volkswagen_2021.pdf
# fname >>> volkswagen_2021.pdf
# doc_id = [112], fname = [volkswagen_2021.pdf]
#
# path + fname >>> reports\vonovia_2020.pdf
# fname >>> vonovia_2020.pdf
# doc_id = [113], fname = [vonovia_2020.pdf]
#
# path + fname >>> reports\VONOVIA_2021.pdf
# fname >>> VONOVIA_2021.pdf
# doc_id = [114], fname = [VONOVIA_2021.pdf]
#
# path + fname >>> reports\Würth_2020.pdf
# fname >>> Würth_2020.pdf
# doc_id = [115], fname = [Würth_2020.pdf]
#
# path + fname >>> reports\Würth_2021.pdf
# fname >>> Würth_2021.pdf
# doc_id = [116], fname = [Würth_2021.pdf]
#
# path + fname >>> reports\Zalando_2020.pdf
# fname >>> Zalando_2020.pdf
# doc_id = [117], fname = [Zalando_2020.pdf]
#
# path + fname >>> reports\Zalando_2021.pdf
# fname >>> Zalando_2021.pdf
# doc_id = [118], fname = [Zalando_2021.pdf]
#
# path + fname >>> reports\ZFfriedrichshafen_2020.pdf
# fname >>> ZFfriedrichshafen_2020.pdf
# doc_id = [119], fname = [ZFfriedrichshafen_2020.pdf]
#
# path + fname >>> reports\ZFfriedrichshafen_2021.pdf
# fname >>> ZFfriedrichshafen_2021.pdf
# doc_id = [120], fname = [ZFfriedrichshafen_2021.pdf]
#
# ==== End of jobs ====
# CPU times: total: 2min 33s
# Wall time: 3min 16s

# %%
df
# Out:
#       doc_id                       fname  \
# 0          0               Aldi_2020.pdf
# 1          0               Aldi_2020.pdf
# 2          0               Aldi_2020.pdf
# 3          0               Aldi_2020.pdf
# 4          0               Aldi_2020.pdf
# ...      ...                         ...
# 3418     120  ZFfriedrichshafen_2021.pdf
# 3419     120  ZFfriedrichshafen_2021.pdf
# 3420     120  ZFfriedrichshafen_2021.pdf
# 3421     120  ZFfriedrichshafen_2021.pdf
# 3422     120  ZFfriedrichshafen_2021.pdf
#
#                                                sentence
# 0     Reduce total weight of own-brand virgin plasti...
# 1     30% recycled content in own-brand plastic pack...
# 2                                        2025 New goal.
# 3     100% sustainably certified and/or recycled mat...
# 4     The requirement refers to all own-brand produc...
# ...                                                 ...
# 3418  Dieser Bericht liegt in deutscher und englisch...
# 3419  Beide Fassungen stehen auch im Internet unter ...
# 3420  Zur besseren Lesbarkeit wird in diesem Geschäf...
# 3421  Es werden damit gleichermaßen alle Geschlechte...
# 3422  Konzept, Text und Gestaltung Berichtsmanufaktu...
#
# [174262 rows x 3 columns]

# %%
df.to_csv(fname_out, index=False)

# %%
# extract company name
df['company'] = df['fname'].str.split('_').apply(lambda x: x[0])

# %%
# extract year of the report
df['year'] = df['fname'].str.split(r'_|\(|\-|\.').apply(lambda x: x[1])

# %%
df.head()
# Out:
#    doc_id          fname                                           sentence  \
# 0       0  Aldi_2020.pdf  Reduce total weight of own-brand virgin plasti...
# 1       0  Aldi_2020.pdf  30% recycled content in own-brand plastic pack...
# 2       0  Aldi_2020.pdf                                     2025 New goal.
# 3       0  Aldi_2020.pdf  100% sustainably certified and/or recycled mat...
# 4       0  Aldi_2020.pdf  The requirement refers to all own-brand produc...
#
#   company  year
# 0    Aldi  2020
# 1    Aldi  2020
# 2    Aldi  2020
# 3    Aldi  2020
# 4    Aldi  2020

# %%
df['word_counts'] = df['sentence'].str.split().str.len()
df_word_cnt = df.groupby(['company','year'])['word_counts'].sum().unstack(level=0)

# %% [markdown]
# ### Export Data to CSV File

# %%
df.to_csv("sentences_company_year.csv", index=False)

# %% [markdown]
# ---

# %%
# End of file
